# %%
import cv2, time

IDX = 12
cap = cv2.VideoCapture(IDX)
ret, frame = cap.read()
print("ret:", ret, "shape:", None if frame is None else frame.shape)
cap.release()
# Out:
# ret: False shape: None
# [ WARN:0] global /tmp/pip-wheel-xjhn4aom/opencv-contrib-python_db9bf2c2b8dd41b592a48d20aac72627/opencv/modules/videoio/src/cap_v4l.cpp (890) open VIDEOIO(V4L2:/dev/video12): can't open camera by index
